# %% [markdown]
# ##### 1.Import libraries that you required and Load the data set.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Zomoto.CSV')

# %%
df
# Out:
#       Unnamed: 0                                                url  \
# 0          14221  https://www.zomato.com/bangalore/shree-ranga-v...
# 1          43422  https://www.zomato.com/bangalore/sphyre-gatewa...
# 2          16032  https://www.zomato.com/bangalore/popular-baker...
# 3          51635  https://www.zomato.com/bangalore/thai-chinese-...
# 4          23424  https://www.zomato.com/bangalore/grill-on-whee...
# ...          ...                                                ...
# 9995       26497  https://www.zomato.com/bangalore/asia-kitchen-...
# 9996       45520  https://www.zomato.com/bangalore/24-hours-cake...
# 9997       41541  https://www.zomato.com/bangalore/tbc-sky-loung...
# 9998       35621  https://www.zomato.com/bangalore/tawa-sagara-j...
# 9999       27432  https://www.zomato.com/bangalore/a3-nuwang-kit...
#
#                                                 address  \
# 0     366, Hosur Main Road, Attibele, Anekal Taluk, ...
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                                                url  \
# 0       14221  https://www.zomato.com/bangalore/shree-ranga-v...
# 1       43422  https://www.zomato.com/bangalore/sphyre-gatewa...
# 2       16032  https://www.zomato.com/bangalore/popular-baker...
# 3       51635  https://www.zomato.com/bangalore/thai-chinese-...
# 4       23424  https://www.zomato.com/bangalore/grill-on-whee...
#
#                                              address  \
# 0  366, Hosur Main Road, Attibele, Anekal Taluk, ...
# 1       Gateway Hotel, 66, Residency Road, Bangalore
# 2                    19, BDA Complex, HSR, Bangalore
# 3  7, Anurhh Arcade, Hoodi Road, Kodigehalli Road...
# 4  Kothanuru Main Road, Puttenahalli Road, Natara...
#
#                        name online_order book_table    rate  votes  \
# 0         Shree Ranga Vilas           No         No   3.2/5      7
# 1    Sphyre - Gateway Hotel           No         No  3.6 /5     45
# ...

# %%
df.shape
# Out:
# (10000, 18)

# %% [markdown]
# ##### 2.Which are the top restaurant chains based on the distribution(frequency) in Bangaluru?

# %%
df.head(5)
# Out:
#    Unnamed: 0                                                url  \
# 0       14221  https://www.zomato.com/bangalore/shree-ranga-v...
# 1       43422  https://www.zomato.com/bangalore/sphyre-gatewa...
# 2       16032  https://www.zomato.com/bangalore/popular-baker...
# 3       51635  https://www.zomato.com/bangalore/thai-chinese-...
# 4       23424  https://www.zomato.com/bangalore/grill-on-whee...
#
#                                              address  \
# 0  366, Hosur Main Road, Attibele, Anekal Taluk, ...
# 1       Gateway Hotel, 66, Residency Road, Bangalore
# 2                    19, BDA Complex, HSR, Bangalore
# 3  7, Anurhh Arcade, Hoodi Road, Kodigehalli Road...
# 4  Kothanuru Main Road, Puttenahalli Road, Natara...
#
#                        name online_order book_table    rate  votes  \
# 0         Shree Ranga Vilas           No         No   3.2/5      7
# 1    Sphyre - Gateway Hotel           No         No  3.6 /5     45
# ...

# %%
chains=df['name'].value_counts()[:10]
chains
# Out:
# Cafe Coffee Day              18
# Keventers                    17
# Onesta                       17
# McDonald's                   16
# SGS Non Veg - Gundu Pulav    16
# The Chocolate Heaven         16
# Baskin Robbins               16
# Mad Over Donuts              15
# Tata Cha                     15
# Petoo                        15
# Name: name, dtype: int64

# %%
sns.barplot(y=chains,x=chains.index)
plt.xticks(rotation=90)
plt.show()

# %%
#Above are the Top 10 restaurant chains

# %% [markdown]
# ##### 3.How many restaurants do not accept online orders?

# %%
df.head()
# Out:
#    Unnamed: 0                                                url  \
# 0       14221  https://www.zomato.com/bangalore/shree-ranga-v...
# 1       43422  https://www.zomato.com/bangalore/sphyre-gatewa...
# 2       16032  https://www.zomato.com/bangalore/popular-baker...
# 3       51635  https://www.zomato.com/bangalore/thai-chinese-...
# 4       23424  https://www.zomato.com/bangalore/grill-on-whee...
#
#                                              address  \
# 0  366, Hosur Main Road, Attibele, Anekal Taluk, ...
# 1       Gateway Hotel, 66, Residency Road, Bangalore
# 2                    19, BDA Complex, HSR, Bangalore
# 3  7, Anurhh Arcade, Hoodi Road, Kodigehalli Road...
# 4  Kothanuru Main Road, Puttenahalli Road, Natara...
#
#                        name online_order book_table    rate  votes  \
# 0         Shree Ranga Vilas           No         No   3.2/5      7
# 1    Sphyre - Gateway Hotel           No         No  3.6 /5     45
# ...

# %%
online_order=df['online_order'].value_counts()

# %%
plt.pie(online_order,labels=online_order.index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ###### 4.What is the ratio b/w restaurants that provide and do not provide table booking?

# %%
df.head(2)
# Out:
#    Unnamed: 0                                                url  \
# 0       14221  https://www.zomato.com/bangalore/shree-ranga-v...
# 1       43422  https://www.zomato.com/bangalore/sphyre-gatewa...
#
#                                              address                    name  \
# 0  366, Hosur Main Road, Attibele, Anekal Taluk, ...       Shree Ranga Vilas
# 1       Gateway Hotel, 66, Residency Road, Bangalore  Sphyre - Gateway Hotel
#
#   online_order book_table    rate  votes                           phone  \
# 0           No         No   3.2/5      7                    080 29765044
# 1           No         No  3.6 /5     45  +91 9886643495\n+91 9898780004
#
#           location      rest_type dish_liked  \
# 0  Electronic City  Casual Dining        NaN
# 1   Residency Road         Lounge        NaN
#
#                                       cuisines approx_cost(for two people)  \
# 0  North Indian, South Indian, Chinese, Juices                         500
# ...

# %%
table_bk=df['book_table'].value_counts()/df.shape[0]*100
table_bk
# Out:
# No     87.54
# Yes    12.46
# Name: book_table, dtype: float64

# %%
plt.pie(table_bk,labels=table_bk.index,autopct='%1.1f%%')
plt.show()

# %%
#Almost nearly 90% of the restaurants do not provide the table booking

# %% [markdown]
# ##### 5.Use a boxplot on the rating column. Use User Defined Function or Lambda function or Apply function to extract the data that comes before /. Kindly exclude /.

# %%
df.head(1)
# Out:
#    Unnamed: 0                                                url  \
# 0       14221  https://www.zomato.com/bangalore/shree-ranga-v...
#
#                                              address               name  \
# 0  366, Hosur Main Road, Attibele, Anekal Taluk, ...  Shree Ranga Vilas
#
#   online_order book_table   rate  votes         phone         location  \
# 0           No         No  3.2/5      7  080 29765044  Electronic City
#
#        rest_type dish_liked                                     cuisines  \
# 0  Casual Dining        NaN  North Indian, South Indian, Chinese, Juices
#
#   approx_cost(for two people)  \
# 0                         500
#
#                                         reviews_list menu_item  \
# 0  [('Rated 3.0', 'RATED\n  Typical South Indian ...        []
#
#   listed_in(type)  listed_in(city)
# 0        Dine-out  Electronic City

# %%
rate=list(map(lambda x:str(x).split('/')[0],df['rate']))

# %%
df['rate']=df['rate'].str.replace(' ','')
df['rate']=df['rate'].str.extract('(\d+\.\d+)').astype(float)

# %%
sns.boxplot(data=df,y=df['rate'])
plt.show()

# %% [markdown]
# ###### 6.Online and Offline orders restaurants percentage.

# %%
df.head(2)
# Out:
#    Unnamed: 0                                                url  \
# 0       14221  https://www.zomato.com/bangalore/shree-ranga-v...
# 1       43422  https://www.zomato.com/bangalore/sphyre-gatewa...
#
#                                              address                    name  \
# 0  366, Hosur Main Road, Attibele, Anekal Taluk, ...       Shree Ranga Vilas
# 1       Gateway Hotel, 66, Residency Road, Bangalore  Sphyre - Gateway Hotel
#
#   online_order book_table  rate  votes                           phone  \
# 0           No         No   3.2      7                    080 29765044
# 1           No         No   3.6     45  +91 9886643495\n+91 9898780004
#
#           location      rest_type dish_liked  \
# 0  Electronic City  Casual Dining        NaN
# 1   Residency Road         Lounge        NaN
#
#                                       cuisines approx_cost(for two people)  \
# 0  North Indian, South Indian, Chinese, Juices                         500
# ...

# %%
online_ord=df['online_order'].value_counts()

# %%
plt.pie(online_ord,labels=online_ord.index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ##### 7. Plot the scatter plot using the Cost vs rating variable with respect to online order. Use apply the function Or other function to remove the “,”.

# %%
df.head(1)
# Out:
#    Unnamed: 0                                                url  \
# 0       14221  https://www.zomato.com/bangalore/shree-ranga-v...
#
#                                              address               name  \
# 0  366, Hosur Main Road, Attibele, Anekal Taluk, ...  Shree Ranga Vilas
#
#   online_order book_table  rate  votes         phone         location  \
# 0           No         No   3.2      7  080 29765044  Electronic City
#
#        rest_type dish_liked                                     cuisines  \
# 0  Casual Dining        NaN  North Indian, South Indian, Chinese, Juices
#
#   approx_cost(for two people)  \
# 0                         500
#
#                                         reviews_list menu_item  \
# 0  [('Rated 3.0', 'RATED\n  Typical South Indian ...        []
#
#   listed_in(type)  listed_in(city)
# 0        Dine-out  Electronic City

# %%
df['approx_cost(for two people)'] = df['approx_cost(for two people)'].apply(lambda x:str(x).replace(',',""))

# %%
df['approx_cost(for two people)'].replace({'nan':np.nan})
# Out:
# 0        500
# 1       1700
# 2        600
# 3        400
# 4        400
#         ...
# 9995    1500
# 9996     700
# 9997    1000
# 9998     NaN
# 9999     300
# Name: approx_cost(for two people), Length: 10000, dtype: object

# %%
df['approx_cost(for two people)'] = df['approx_cost(for two people)'].astype(float)

# %%
sns.scatterplot(y=df['approx_cost(for two people)'],x=df['rate'])
plt.show()

# %% [markdown]
# ##### 8.	Find the distribution of the votes and Approx_cost using a user-defined function and for a loop.

# %%
sns.displot(df[['votes','approx_cost(for two people)']],kind='kde')

# %% [markdown]
# ##### 9.Which are the most common restaurant type in Banglore?

# %%
df.head(2)
# Out:
#    Unnamed: 0                                                url  \
# 0       14221  https://www.zomato.com/bangalore/shree-ranga-v...
# 1       43422  https://www.zomato.com/bangalore/sphyre-gatewa...
#
#                                              address                    name  \
# 0  366, Hosur Main Road, Attibele, Anekal Taluk, ...       Shree Ranga Vilas
# 1       Gateway Hotel, 66, Residency Road, Bangalore  Sphyre - Gateway Hotel
#
#   online_order book_table  rate  votes                           phone  \
# 0           No         No   3.2      7                    080 29765044
# 1           No         No   3.6     45  +91 9886643495\n+91 9898780004
#
#           location      rest_type dish_liked  \
# 0  Electronic City  Casual Dining        NaN
# 1   Residency Road         Lounge        NaN
#
#                                       cuisines  approx_cost(for two people)  \
# 0  North Indian, South Indian, Chinese, Juices                        500.0
# ...

# %%
rest_type=df['rest_type'].value_counts().head(10)

# %%
sns.barplot(y=rest_type,x=rest_type.index)
plt.xticks(rotation=90)
plt.show()

# %%
#Quick bytes is the most common restaurant type

# %% [markdown]
# ##### 10.	Is there any difference b/w the votes of restaurants accepting and not accepting online orders?

# %%
df.head(2)
# Out:
#    Unnamed: 0                                                url  \
# 0       14221  https://www.zomato.com/bangalore/shree-ranga-v...
# 1       43422  https://www.zomato.com/bangalore/sphyre-gatewa...
#
#                                              address                    name  \
# 0  366, Hosur Main Road, Attibele, Anekal Taluk, ...       Shree Ranga Vilas
# 1       Gateway Hotel, 66, Residency Road, Bangalore  Sphyre - Gateway Hotel
#
#   online_order book_table  rate  votes                           phone  \
# 0           No         No   3.2      7                    080 29765044
# 1           No         No   3.6     45  +91 9886643495\n+91 9898780004
#
#           location      rest_type dish_liked  \
# 0  Electronic City  Casual Dining        NaN
# 1   Residency Road         Lounge        NaN
#
#                                       cuisines  approx_cost(for two people)  \
# 0  North Indian, South Indian, Chinese, Juices                        500.0
# ...

# %%
df.groupby('online_order')['votes'].agg(['sum','mean'])
# Out:
#                   sum        mean
# online_order
# No            1128442  278.146907
# Yes           1795484  302.117449

# %% [markdown]
# Yes there is a difference b/w the restaurants that accepting and not accepting online orders. Restaurants which accept online orders has more number of votes compared to restaurants not accepting online orders

# %% [markdown]
# ##### 12.	Find the Best budget Restaurants in any location.

# %%
df.head(2)
# Out:
#    Unnamed: 0                                                url  \
# 0       14221  https://www.zomato.com/bangalore/shree-ranga-v...
# 1       43422  https://www.zomato.com/bangalore/sphyre-gatewa...
#
#                                              address                    name  \
# 0  366, Hosur Main Road, Attibele, Anekal Taluk, ...       Shree Ranga Vilas
# 1       Gateway Hotel, 66, Residency Road, Bangalore  Sphyre - Gateway Hotel
#
#   online_order book_table  rate  votes                           phone  \
# 0           No         No   3.2      7                    080 29765044
# 1           No         No   3.6     45  +91 9886643495\n+91 9898780004
#
#           location      rest_type dish_liked  \
# 0  Electronic City  Casual Dining        NaN
# 1   Residency Road         Lounge        NaN
#
#                                       cuisines  approx_cost(for two people)  \
# 0  North Indian, South Indian, Chinese, Juices                        500.0
# ...

# %%
df.groupby('name')['approx_cost(for two people)'].mean().sort_values().reset_index().head(10)
# Out:
#                           name  approx_cost(for two people)
# 0        Srinidhi Sagar Deluxe                         40.0
# 1            Nellore Dosa Camp                         70.0
# 2                      Namaste                         70.0
# 3            S R & Sons Bakery                        100.0
# 4  Sri Annapoorna Bajji Center                        100.0
# 5                     Cane Hut                        100.0
# 6              Nammura Upahara                        100.0
# 7                Momo Junction                        100.0
# 8                 Taaza Thindi                        100.0
# 9        Oyo Empire Juice Shop                        100.0

# %% [markdown]
# Srinidhi Sagar Deluxe is a budget restaurant

# %% [markdown]
# ##### 13.	Top quick bites restaurant chains in Banglore.

# %%
df.head(1)
# Out:
#    Unnamed: 0                                                url  \
# 0       14221  https://www.zomato.com/bangalore/shree-ranga-v...
#
#                                              address               name  \
# 0  366, Hosur Main Road, Attibele, Anekal Taluk, ...  Shree Ranga Vilas
#
#   online_order book_table  rate  votes         phone         location  \
# 0           No         No   3.2      7  080 29765044  Electronic City
#
#        rest_type dish_liked                                     cuisines  \
# 0  Casual Dining        NaN  North Indian, South Indian, Chinese, Juices
#
#    approx_cost(for two people)  \
# 0                        500.0
#
#                                         reviews_list menu_item  \
# 0  [('Rated 3.0', 'RATED\n  Typical South Indian ...        []
#
#   listed_in(type)  listed_in(city)       city
# 0        Dine-out  Electronic City  bangalore

# %%
df[(df['rest_type']=='Quick Bites')&(df['city']==
                                     'bangalore')].groupby('name')['rate'].mean().sort_values(ascending=False).reset_index()
# Out:
#                         name  rate
# 0                        CTR   4.7
# 1               Taaza Thindi   4.7
# 2               Veena Stores   4.5
# 3      Chikkanna Tiffin Room   4.5
# 4             The Bundle Co.   4.4
# ...                      ...   ...
# 1987      Yummy Dum Biriyani   NaN
# 1988             Zafron Cafe   NaN
# 1989  Zam Zam Biriyani Hotel   NaN
# 1990               Zing Roll   NaN
# 1991             Zuiqa Taste   NaN
#
# [1992 rows x 2 columns]

# %% [markdown]
# ##### 14.	Which are the most popular casual dining restaurant chains, Make use of any plot related to this question?

# %%
df.head(1)
# Out:
#    Unnamed: 0                                                url  \
# 0       14221  https://www.zomato.com/bangalore/shree-ranga-v...
#
#                                              address               name  \
# 0  366, Hosur Main Road, Attibele, Anekal Taluk, ...  Shree Ranga Vilas
#
#   online_order book_table  rate  votes         phone         location  \
# 0           No         No   3.2      7  080 29765044  Electronic City
#
#        rest_type dish_liked                                     cuisines  \
# 0  Casual Dining        NaN  North Indian, South Indian, Chinese, Juices
#
#    approx_cost(for two people)  \
# 0                        500.0
#
#                                         reviews_list menu_item  \
# 0  [('Rated 3.0', 'RATED\n  Typical South Indian ...        []
#
#   listed_in(type)  listed_in(city)       city
# 0        Dine-out  Electronic City  bangalore

# %%
cas_dine=df[(df['rest_type']==
             'Casual Dining')].groupby('name')['rate'].mean().sort_values(ascending=False).reset_index().head(15)

# %%
sns.barplot(x=cas_dine['name'],y=cas_dine['rate'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 15.	Which are the most popular cuisines of Bangalore using a related plot?

# %%
df.head(1)
# Out:
#    Unnamed: 0                                                url  \
# 0       14221  https://www.zomato.com/bangalore/shree-ranga-v...
#
#                                              address               name  \
# 0  366, Hosur Main Road, Attibele, Anekal Taluk, ...  Shree Ranga Vilas
#
#   online_order book_table  rate  votes         phone         location  \
# 0           No         No   3.2      7  080 29765044  Electronic City
#
#        rest_type dish_liked                                     cuisines  \
# 0  Casual Dining        NaN  North Indian, South Indian, Chinese, Juices
#
#    approx_cost(for two people)  \
# 0                        500.0
#
#                                         reviews_list menu_item  \
# 0  [('Rated 3.0', 'RATED\n  Typical South Indian ...        []
#
#   listed_in(type)  listed_in(city)       city
# 0        Dine-out  Electronic City  bangalore

# %%
cuisines=df[(df['city']=='bangalore')].groupby('cuisines')['rate'].mean().sort_values(ascending=False).reset_index()
cuisines
# Out:
#                                         cuisines  rate
# 0        Asian, Mediterranean, North Indian, BBQ   4.9
# 1     European, Mediterranean, North Indian, BBQ   4.9
# 2                    Asian, Chinese, Thai, Momos   4.9
# 3                      Italian, Pizza, Beverages   4.8
# 4     North Indian, European, Mediterranean, BBQ   4.8
# ...                                          ...   ...
# 1722                         Street Food, Burger   NaN
# 1723                         Street Food, Juices   NaN
# 1724     Street Food, Sandwich, Rolls, Beverages   NaN
# 1725  Tamil, South Indian, North Indian, Chinese   NaN
# 1726                            Tibetan, Chinese   NaN
#
# [1727 rows x 2 columns]

# %%
cuisines['rank']=cuisines['rate'].rank(method='dense',ascending=False)

# %%
top10_cuisines=cuisines.head(10)
top10_cuisines
# Out:
#                                             cuisines  rate  rank
# 0            Asian, Mediterranean, North Indian, BBQ   4.9   1.0
# 1         European, Mediterranean, North Indian, BBQ   4.9   1.0
# 2                        Asian, Chinese, Thai, Momos   4.9   1.0
# 3                          Italian, Pizza, Beverages   4.8   2.0
# 4         North Indian, European, Mediterranean, BBQ   4.8   2.0
# 5  Continental, North Indian, Chinese, European, ...   4.8   2.0
# 6   Goan, Asian, North Indian, European, Continental   4.7   3.0
# 7  Chinese, American, Continental, Italian, North...   4.7   3.0
# 8  American, Continental, North Indian, Mediterra...   4.7   3.0
# 9              North Indian, European, Mediterranean   4.7   3.0

# %%
sns.barplot(data=top5_cuisines,x='cuisines',y='rate')
plt.xticks(rotation=90)
plt.show()
